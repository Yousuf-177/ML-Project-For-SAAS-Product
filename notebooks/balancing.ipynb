# %% [markdown]
# ### **Import Libraries & Functions**

# %%
import sys
from pathlib import Path
import pandas as pd

# %%
PROJECT_ROOT = Path(r"D:\Project").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from utils.utils import load_data, target_balance

# %% [markdown]
# ### **Read Interim Data**

# %%
df = load_data("interim/interim_data.csv")
df.head(3)
# Out:
#    age  gender country company_size       industry job_title  \
# 0   60  Female     USA   201 to 500      Education   Manager
# 1   50  Female  Canada    51 to 200  Manufacturing       CEO
# 2   36    Male  France     11 to 50     Healthcare       CEO
#
#    annual_company_revenue plan_type  months_as_customer  total_spend  ...  \
# 0                75849462   Starter                  32          517  ...
# 1                16239921   Starter                  25          481  ...
# 2                 2436035      Free                  52            0  ...
#
#    product_tours_completed  onboarding_completed  support_tickets_total  \
# 0                        1                     1                      9
# 1                        1                     0                     16
# 2                        4                     1                     10
#
#    avg_ticket_resolution_hours  sat_score  campaigns_received  \
# 0                          5.9          5                   7
# 1                         26.3          4                   7
# 2                          2.8          3                  15
#
#    last_marketing_touch_days_ago  attended_webinar  social_media_engaged  \
# 0                            100                 0                     1
# 1                            171                 0                     0
# 2                             66                 0                     0
#
#    will_repurchase
# 0                0
# 1                0
# 2                1
#
# [3 rows x 28 columns]

# %% [markdown]
# ### **Check Distribution**

# %%
target_balance(df, "will_repurchase")
# Out:
#                  count     pct
# will_repurchase
# 1                 6269  0.6269
# 0                 3731  0.3731
