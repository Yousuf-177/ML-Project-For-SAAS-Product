# %% [markdown]
# ### **Import Libraries & Functions**

# %%
import sys
import pandas as pd
from pathlib import Path
import numpy as np

# %%
PROJECT_ROOT = Path(r"D:\Project").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from utils.utils import load_data, data_checkup, check_multicollinearity

# %% [markdown]
# ### **Read Raw Data**

# %%
df = load_data("raw/saas_lead.csv")
df.head(3)
# Out:
#   customer_id  age  gender country company_size       industry job_title  \
# 0  CUST-00001   60  Female     USA   201 to 500      Education   Manager
# 1  CUST-00002   50  Female  Canada    51 to 200  Manufacturing       CEO
# 2  CUST-00003   36    Male  France     11 to 50     Healthcare       CEO
#
#    annual_company_revenue plan_type  months_as_customer  ...  \
# 0                75849462   Starter                  32  ...
# 1                16239921   Starter                  25  ...
# 2                 2436035      Free                  52  ...
#
#    product_tours_completed  onboarding_completed  support_tickets_total  \
# 0                        1                     1                      9
# 1                        1                     0                     16
# 2                        4                     1                     10
#
#    avg_ticket_resolution_hours  sat_score  campaigns_received  \
# 0                          5.9          5                   7
# ...

# %% [markdown]
# ### **Data Eyebaling**

# %%
pd.set_option('display.float_format', '{:.4f}'.format)
pd.set_option('display.max_colwidth', None)

num_df, cat_df = data_checkup(df)

# %%
num_df
# Out:
#                            column  num_rows  num_nulls        min  \
# 0                             age     10000          0    22.0000
# 1          annual_company_revenue     10000          0 50157.0000
# 2              months_as_customer     10000          0     1.0000
# 3                     total_spend     10000          0     0.0000
# 4                   num_purchases     10000          0     1.0000
# 5          last_purchase_days_ago     10000          0     1.0000
# 6              has_churned_before     10000          0     0.0000
# 7                   discount_used     10000          0     0.0000
# 8             monthly_active_days     10000          0     0.0000
# 9        avg_session_duration_min     10000          0     0.0000
# 10            features_used_count     10000          0     1.0000
# 11         api_calls_last_30_days     10000          0     5.0000
# 12        product_tours_completed     10000          0     0.0000
# ...

# %%
cat_df
# Out:
#          column  num_rows  num_nulls  \
# 0   customer_id     10000          0
# 1        gender     10000          0
# 2       country     10000          0
# 3  company_size     10000          0
# 4      industry     10000          0
# 5     job_title     10000          0
# 6     plan_type     10000          0
#
# ...

# %% [markdown]
# ### **Check Multicolinarity**

# %%
vif_df = check_multicollinearity(df, threshold=5.0)
display(vif_df)
# Out:
#                           feature     VIF  high_vif
# 0                             age 10.7417      True
# 1                       sat_score 10.5377      True
# 2             monthly_active_days  4.6530     False
# 3             features_used_count  4.0807     False
# 4                   num_purchases  4.0674     False
# 5          last_purchase_days_ago  4.0490     False
# 6              months_as_customer  3.9187     False
# 7          api_calls_last_30_days  3.8741     False
# 8   last_marketing_touch_days_ago  3.8012     False
# 9                 will_repurchase  3.7957     False
# 10             campaigns_received  3.6511     False
# 11          support_tickets_total  3.5211     False
# 12           onboarding_completed  3.3134     False
# 13        product_tours_completed  2.8769     False
# 14    avg_ticket_resolution_hours  1.9566     False
# 15       avg_session_duration_min  1.9496     False
# 16                  discount_used  1.7804     False
# ...

# %%
# Check corr between age and satisfaction_score
df[['age', 'sat_score']].corr()
# Out:
#              age  sat_score
# age       1.0000     0.0110
# sat_score 0.0110     1.0000

# %%
# Check corr between age and other numeric features
num_df = df.select_dtypes(include=['number']).drop(columns=['will_repurchase'])
num_df.corr()['age'].sort_values(ascending=False)
# Out:
# age                              1.0000
# months_as_customer               0.0224
# total_spend                      0.0135
# has_churned_before               0.0123
# sat_score                        0.0110
# annual_company_revenue           0.0108
# campaigns_received               0.0090
# support_tickets_total            0.0078
# num_purchases                    0.0066
# monthly_active_days              0.0056
# avg_session_duration_min         0.0026
# last_purchase_days_ago           0.0026
# product_tours_completed          0.0017
# last_marketing_touch_days_ago   -0.0018
# avg_ticket_resolution_hours     -0.0026
# api_calls_last_30_days          -0.0028
# attended_webinar                -0.0037
# features_used_count             -0.0042
# social_media_engaged            -0.0148
# discount_used                   -0.0173
# onboarding_completed            -0.0179
# Name: age, dtype: float64

# %%
# Check corr between satisfaction_score and other numeric features
num_df = df.select_dtypes(include=['number']).drop(columns=['will_repurchase'])
num_df.corr()['sat_score'].sort_values(ascending=False)
# Out:
# sat_score                        1.0000
# num_purchases                    0.0119
# last_marketing_touch_days_ago    0.0113
# age                              0.0110
# discount_used                    0.0092
# social_media_engaged             0.0038
# features_used_count              0.0037
# avg_session_duration_min         0.0036
# last_purchase_days_ago           0.0031
# onboarding_completed             0.0022
# product_tours_completed          0.0009
# total_spend                      0.0009
# api_calls_last_30_days           0.0006
# months_as_customer              -0.0015
# campaigns_received              -0.0023
# annual_company_revenue          -0.0026
# has_churned_before              -0.0038
# monthly_active_days             -0.0064
# attended_webinar                -0.0104
# support_tickets_total           -0.0252
# avg_ticket_resolution_hours     -0.0277
# Name: sat_score, dtype: float64
